# %%
# Run me!  See today's paper sheet for the plan.
import random
side = 1
volume = 0

### TODO ###
side = int(input('Side length? '))
volume = side ** 3
print('Volume:', volume)
for i in range(2):
    test = random.randint(1,3)
    print('Try', test, '->', test ** 3)
