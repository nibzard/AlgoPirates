# %%
# Run me!  See today's paper sheet for the plan.
colors = ['🟥', '🟦', '🟩']
denominators = [2, 3, 4, 6]
for d in denominators:
    row = ''
    for i in range(d):
        row += colors[i % len(colors)]
    print(f"{d} parts:", row)

print()

### TODO ###
# Add a row for eighths using your own color pattern.
# Try changing the colors list as well.
