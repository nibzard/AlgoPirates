# %%
# Run me!  See today's paper sheet for the plan.
import random
height = 0
blocks = []
for step in range(5):
    block = random.randint(1,3)
    blocks.append(block)
    height += block
    print('Step', step + 1, 'height:', height)

### TODO ###
# Change the loop to 10 steps and experiment!
